# %%
def zero(a=None):
    if a:
        return a(0)
    return 0

def one(a=None):
    if a:
        return a(1)
    return 1

def two(a=None):
    if a:
        return a(2)
    return 2

def three(a=None):
    if a:
        return a(3)
    return 3

def four(a=None):
    if a:
        return a(4)
    return 4

def five(a=None):
    if a:
        return a(5)
    return 5

def six(a=None):
    if a:
        return a(6)
    return 6

def seven(a=None):
    if a:
        return a(7)
    return 7

def eight(a=None):
    if a:
        return a(8)
    return 8

def nine(a=None):
    if a:
        return a(9)
    return 9

def plus(y):
    def inner(x):
        return x + y
    return inner

def minus(y):
    def inner(x):
        return x - y
    return inner

def times(y):
    def inner(x):
        return x * y
    return inner

def divided_by(y):
    def inner(x):
        return x // y
    return inner



print(seven(times(five())))

print(four(plus(nine())))

print(eight(minus(three())))

print(six(divided_by(two())))
# Out:
# 35
# 13
# 5
# 3
